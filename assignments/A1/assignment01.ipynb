# %% [raw]
# Q3] To write a centrality measure as a function from scratch with input = target node & networkx graph.

# %%
import networkx as nx
import numpy as np
from itertools import combinations
import random

# %% [markdown]
# FIRST ATTEMPT: BETWEENNESS CENTRALITY

# %%
#number of ways to choose r elements from a set of n elements.
def nCr(n, r):

    return (fact(n) / (fact(r)
                * fact(n - r)))

# Returns factorial of n
def fact(n):
    if n == 0 or n==1:
        return 1
    res = 1

    for i in range(2, n+1):
        res = res * i

    return res

#G = networkx graph
#n = target node

def betweenness_centrality_scratch(G,input_node):

    centrality = 0.00000
    N = len(G)
    iter = nCr(N,2)

    for s,t in combinations(G.nodes(),2):
      if s == input_node or t == input_node:
          continue


      paths = nx.all_shortest_paths(G, source=s, target=t)
      all_paths = list(paths)
      path_count = len(all_paths)

      if path_count == 0:
        continue

      paths_through_input_node = sum(1 for path in paths if input_node in path[1:-1])
      centrality += paths_through_input_node
        

    if nx.is_directed(G) is True:
        factor = 1 / ((N - 1) * (N - 2)) #For a directed network
    else:
        factor = 2 / ((N - 1) * (N - 2)) #For an undirected network

    centrality = centrality * factor


    return centrality

# %%
G = nx.gnp_random_graph(10, 0.5)

# %%
nx.betweenness_centrality(G)
# Out:
# {0: 0.07824074074074074,
#  1: 0.07384259259259258,
#  2: 0.02546296296296296,
#  3: 0.12800925925925927,
#  4: 0.062037037037037036,
#  5: 0.048611111111111105,
#  6: 0.04513888888888889,
#  7: 0.07499999999999998,
#  8: 0.1511574074074074,
#  9: 0.062499999999999986}

# %%
betweenness_centrality_scratch(G,7)
# Out:
# 0.0

# %% [markdown]
# The function is not able to calculate betweenness centrality as expected. Due to time contstraints I switched to closeness centrality. Th efollowing function takes into account both Qs 3 a and b.

# %%
def closeness_centrality_from_scratch(G, input_node):

    centrality = 0
    N = G.number_of_nodes()  # Total number of nodes in the graph

    if input_node not in G.nodes():
      print("Input node not found in the graph.")
      return None

    if not isinstance(G, nx.Graph):
      print("Input graph is not a NetworkX object.")
      return None

    is_connected = nx.is_connected(G)
    if not is_connected:
      print("Input graph is not connected.")
      return None

    if N <= 1:
      print("Input graph has less than 2 nodes.")
      return None

    # Compute shortest paths from input_nodeto all other nodes
    shortest_paths = nx.shortest_path_length(G, source=input_node)
    #print( shortest_paths)

        # Sum the lengths of the shortest paths
    total_distance = sum(shortest_paths.values())
    #print(total_distance)

        # Closeness centrality calculation (ignoring disconnected components)
    if total_distance > 0 and N > 1:
        centrality = (N - 1) / total_distance
    else:
        centrality = 0.0  # In case the node is isolated

    return centrality

# %%
G = nx.gnp_random_graph(10, 0.5)

# %%
closeness_centrality_from_scratch(G,1)
# Out:
# 0.6923076923076923

# %%
nx.closeness_centrality(G)
# Out:
# {0: 0.6428571428571429,
#  1: 0.6923076923076923,
#  2: 0.5625,
#  3: 0.6428571428571429,
#  4: 0.5625,
#  5: 0.6923076923076923,
#  6: 0.6428571428571429,
#  7: 0.8181818181818182,
#  8: 0.75,
#  9: 0.6923076923076923}

# %%
#Testing on a weighted graph 
Gw = nx.Graph()

Gw.add_edge("a", "b", weight=0.6)
Gw.add_edge("a", "c", weight=0.2)
Gw.add_edge("c", "d", weight=0.1)
Gw.add_edge("c", "e", weight=0.7)
Gw.add_edge("c", "f", weight=0.9)
Gw.add_edge("a", "d", weight=0.3)

# %%
nx.closeness_centrality(Gw)
# Out:
# {'a': 0.7142857142857143,
#  'b': 0.45454545454545453,
#  'c': 0.8333333333333334,
#  'd': 0.625,
#  'e': 0.5,
#  'f': 0.5}

# %%
closeness_centrality_from_scratch(Gw,"a")
# Out:
# 0.7142857142857143

# %%
#Testing a directed graph 
Gs = nx.complete_graph(3, create_using=nx.DiGraph)

#Gs.add_edges_from(edgelist)

# %%
nx.closeness_centrality(Gs)
# Out:
# {0: 1.0, 1: 1.0, 2: 1.0}

# %%
closeness_centrality_from_scratch(Gs,1)
# Out:
# ---------------------------------------------------------------------------
# NetworkXNotImplemented                    Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 closeness_centrality_from_scratch(Gs,1)
#
# Cell In[6], line 14, in closeness_centrality_from_scratch(G, input_node)
#      11   print("Input graph is not a NetworkX object.")
#      12   return None
# ---> 14 is_connected = nx.is_connected(G)
#      15 if not is_connected:
#      16   print("Input graph is not connected.")
#
# File <class 'networkx.utils.decorators.argmap'> compilation 23:3, in argmap_is_connected_19(G, backend, **backend_kwargs)
#       1 import bz2
#       2 import collections
# ----> 3 import gzip
#       4 import inspect
#       5 import itertools
#
# File /courses/PHYS7332.202510/shared/phys7332-env/lib/python3.12/site-packages/networkx/utils/decorators.py:92, in not_implemented_for.<locals>._not_implemented_for(g)
#      88 def _not_implemented_for(g):
#      89     if (mval is None or mval == g.is_multigraph()) and (
#      90         dval is None or dval == g.is_directed()
#      91     ):
# ---> 92         raise nx.NetworkXNotImplemented(errmsg)
#      94     return g
#
# NetworkXNotImplemented: not implemented for directed type

# %%
#Testing undirected graph with selfloops
Gl = nx.gnp_random_graph(10, 0.5)
edgelist = [(1, 1), (2, 2)]
Gl.add_edges_from(edgelist)

# %%
nx.closeness_centrality(Gl)
# Out:
# {0: 0.8181818181818182,
#  1: 0.5625,
#  2: 0.6923076923076923,
#  3: 0.6,
#  4: 0.6,
#  5: 0.6,
#  6: 0.6923076923076923,
#  7: 0.75,
#  8: 0.75,
#  9: 0.6428571428571429}

# %%
closeness_centrality_from_scratch(Gl,1)
# Out:
# 0.5625

# %% [markdown]
# To test the centrality function for robustness

# %%
def test_centrality(your_function):
    #We start by defining the test cases 
    test_cases = [
        ("Empty Graph", nx.Graph()),
         ("Directed Graph", nx.complete_graph(5, create_using=nx.DiGraph)),
         ("Path Graph", nx.path_graph(5)),
         ("Disconnected Components", nx.Graph([(0, 1), (2, 3),(4,5)])),
    ]
    for test_name, G in test_cases:
        print(f"\nTest Case: {test_name}")
        if G.number_of_nodes() == 0:
            print("Graph is empty.")
            continue
        for node_i in G.nodes():
            try:
                centrality = your_function(G, node_i)
                print(f"Node {node_i}: Centrality = {centrality}")
            except Exception as e:
                print(f"Error for node {node_i}: {e}")

# %%
test_centrality(closeness_centrality_from_scratch)
# Out:
# Test Case: Empty Graph
# Graph is empty.
#
# Test Case: Directed Graph
# Error for node 0: not implemented for directed type
# Error for node 1: not implemented for directed type
# Error for node 2: not implemented for directed type
# Error for node 3: not implemented for directed type
# Error for node 4: not implemented for directed type
#
# Test Case: Path Graph
# Node 0: Centrality = 0.4
# Node 1: Centrality = 0.5714285714285714
# Node 2: Centrality = 0.6666666666666666
# Node 3: Centrality = 0.5714285714285714
# Node 4: Centrality = 0.4
#
# Test Case: Disconnected Components
# Input graph is not connected.
# Node 0: Centrality = None
# Input graph is not connected.
# Node 1: Centrality = None
# Input graph is not connected.
# Node 2: Centrality = None
# Input graph is not connected.
# Node 3: Centrality = None
# Input graph is not connected.
# Node 4: Centrality = None
# Input graph is not connected.
# Node 5: Centrality = None

# %%
test_centrality(nx.closeness_centrality)
# Out:
# Test Case: Empty Graph
# Graph is empty.
#
# Test Case: Directed Graph
# Node 0: Centrality = 1.0
# Node 1: Centrality = 1.0
# Node 2: Centrality = 1.0
# Node 3: Centrality = 1.0
# Node 4: Centrality = 1.0
#
# Test Case: Path Graph
# Node 0: Centrality = 0.4
# Node 1: Centrality = 0.5714285714285714
# Node 2: Centrality = 0.6666666666666666
# Node 3: Centrality = 0.5714285714285714
# Node 4: Centrality = 0.4
#
# Test Case: Disconnected Components
# Node 0: Centrality = 0.2
# Node 1: Centrality = 0.2
# Node 2: Centrality = 0.2
# Node 3: Centrality = 0.2
# Node 4: Centrality = 0.2
# Node 5: Centrality = 0.2

# %% [markdown]
# Qs 4]

# %%
from IPython.display import display, HTML
import requests
from bs4 import BeautifulSoup
import random
import re
import matplotlib.pyplot as plt

# %%
def course_prereq(dept_html):
    course_dict = {}
    
    soup = BeautifulSoup(dept_html, 'html.parser')
    col_content_div = soup.find('div', id="col-content")
    coursedesc = col_content_div.find("div", class_="sc_sccoursedescs")
    if coursedesc:
        courseblocks = coursedesc.find_all("div", class_="courseblock")
        for courseblock in courseblocks:
            # Find prerequisites inside courseblockextra
            courseblock_extra = courseblock.find("p", class_="courseblockextra")
            if courseblock_extra and "Prerequisite" in courseblock_extra.text:
                # Find all prerequisite links (a tags)
                prereq_links = courseblock_extra.find_all("a")
                prereq_courses = []
                for link in prereq_links:
                    # Extract the course code from the href attribute (after '?P=')
                    href = link.get('href')
                    prereq_course_code = href.split('?P=')[-1]  # Get the course code from the query string
                    prereq_course_code = re.sub(r'20|%', '', prereq_course_code).strip()
                    prereq_courses.append(prereq_course_code)
                    # Join the course codes when multiple prerequisites exist
                    prerequisites = ' , '.join(prereq_courses)
            
                    # Get the course code for the current course
                    c_title = courseblock.find("p", class_="courseblocktitle")
                    if c_title:
                        # Extract the course code from the title
                        # Assuming the course code is the first part before a period
                        course_code = c_title.text.split('.')[0].strip()  # Extract course code before the first period
                        course_code = course_code.replace('\xa0', '') 
                        course_dict[course_code] = prerequisites
    
    return course_dict

# %%
dept_html = requests.get('https://catalog.northeastern.edu/course-descriptions/jrnl/').text
course_dict = course_prereq(dept_html)
course_dict
# Out:
# {'JRNL2200': 'ENGW1102 , ENGW1111',
#  'JRNL2201': 'JRNL1101',
#  'JRNL2301': 'ENGW1111 , ENGW1102',
#  'JRNL2350': 'ENGW1111 , ENGW1102',
#  'JRNL4370': 'COMM1450 , JRNL1101 , JRNL3370',
#  'JRNL5314': 'JRNL21',
#  'JRNL6201': 'JRNL60',
#  'JRNL6307': 'JRNL6306'}

# %% [markdown]
# Visualization of the pre-requisites to courses connectivity for this department.

# %%
def generate_course_network(course_dict):
    
    G = nx.DiGraph()

    # Iterate over the course dictionary
    for course, prereqs in course_dict.items():
        # Split prerequisites if they are joined by ','
        prereq_list = prereqs.split(' , ')
        
        # Add an edge from each prerequisite to the course
        for prereq in prereq_list:
             # Clean up the prerequisite URLs (optional, depending on how you store them)
             prereq_cleaned = prereq.split('?P=')[-1]  # Extract course code from the URL
             G.add_edge(prereq_cleaned, course)

    return G

def visualize_course_network(G):
    # Draw the graph
    pos = nx.spring_layout(G, k=3, iterations=100)  # Spring layout for a clean visualization
    plt.figure(figsize=(10, 8))
    nx.draw(G, pos, with_labels=True, node_color='lightblue', font_weight='bold', node_size=3000, font_size=6, arrowsize=20)
    plt.title("Course-Prerequisite Network")
    plt.show()

# %%
G = generate_course_network(course_dict)
visualize_course_network(G)

# %% [markdown]
# To generate a network of the entire curriculum

# %%
catalog_res = requests.get('https://catalog.northeastern.edu/course-descriptions/')
catalog_html = catalog_res.text
soup = BeautifulSoup(catalog_html)
soup_alpha_div = soup.find('div', id="atozindex")
department_hrefs = []
for ul in soup_alpha_div.find_all('ul'):
    for li in ul.find_all('li'):
        department_hrefs.append(li.a.get('href'))

all_depts = []
for url in department_hrefs:
    dept = 'https://catalog.northeastern.edu' + url
    all_depts.append(dept)

#all_depts

# %%
def fetch_html(url):
    """
    Fetch the HTML content of a given URL.
    """
    response = requests.get(url)
    if response.status_code == 200:
        return response.text
    else:
        print(f"Failed to fetch {url}")
        return None

def all_dept_prereq(url_list):
    """
    Iterate over a list of URLs, fetch HTML content, and generate combined course-prerequisite dictionaries.
    """
    curriculum_dict = {}

    # Loop over each URL
    for url in url_list:
        html_content = fetch_html(url)
        if html_content:
            # Generate the course-prerequisite dictionary for this page
            #print(html_content)
            course_dict = course_prereq(html_content)
            
            # Merge the dictionaries into the combined dictionary
            curriculum_dict.update(course_dict)
    
    return curriculum_dict

# %%
curriculum_dict = all_dept_prereq(all_depts)

# %%
curriculum_dict
# Out:
# {'ACCT2301': 'ACCT11 , ACCT19',
#  'ACCT3304': 'ACCT2301',
#  'ACCT3401': 'ACCT2301',
#  'ACCT3402': 'ACCT2301',
#  'ACCT3403': 'ACCT2301',
#  'ACCT3416': 'ACCT2301',
#  'ACCT4412': 'ACCT3401',
#  'ACCT4414': 'ACCT2301',
#  'ACCT4501': 'ACCT3401',
#  'ACCT5204': 'ACCT51',
#  'ACCT5220': 'ACCT2301 , ACCT67',
#  'ACCT5232': 'ACCT5230 , ACCT5230',
#  'ACCT6201': 'ACCT60',
#  'ACCT6204': 'ACCT63',
#  'ACCT6221': 'ACCT62',
#  'ACCT6222': 'ACCT6221',
#  'ACCT6223': 'ACCT6221',
#  'ACCT6224': 'ACCT6221',
#  'ACCT6226': 'ACCT6221',
#  'ACCT6227': 'ACCT6221',
#  'ACCT6228': 'ACCT6221',
#  'ACCT6231': 'ACCT5230 , ACCT5230',
#  'ACCT6235': 'ACCT5230 , ACCT5230',
#  'ACCT6239': 'ACCT5230 , ACCT5230',
#  'ACCT6240': 'ACCT6231 , ACCT6235',
#  'ACCT6241': 'ACCT6231 , ACCT6235',
#  'ACCT6243': 'ACCT6231 , ACCT6235',
#  'ACCT6250': 'ACCT5232',
#  'ACCT6273': 'ACCT6272',
#  'ACC3201': 'ACC2100',
#  'ACC3202': 'ACC31',
#  'ACC3330': 'ACC32',
#  'ACC3410': 'ACC31',
#  'ACC4320': 'ACC32 , FIN3310 , ACC3410',
#  'ACC4410': 'ACC3410',
#  'ACC4420': 'ACC32 , ACC3410',
#  'ACC6230': 'ACC6210 , ACC62',
#  'AVM3100': 'MET3300',
#  'AVM3500': 'MGT22',
#  'AVM4100': 'MET00 , EET3100 , EET3300',
#  'AVM4150': 'EET3300',
#  'AVM4160': 'AVM4150',
#  'AVM4250': 'MTH2105 , PHY10',
#  'AVM4300': 'AVM1150',
#  'AFCS2296': 'ENGW1111 , ENGW1102 , ENGW1113 , ENGW1114',
#  'AFCS2318': 'ENGW1102 , ENGW1111 , ENGW1113 , ENGW1114',
#  'AFCS2325': 'ENGW1102 , ENGW1111 , ENGW1113 , ENGW1114',
#  'AFCS2337': 'ENGW1102 , ENGW1111 , ENGW1113 , ENGW1114',
#  'AFCS2355': 'ENGW1102 , ENGW1111 , ENGW1113 , ENGW1114',
#  'AFCS2380': 'ENGW1102 , ENGW1111 , ENGW1113 , ENGW1114',
#  'AFCS2455': 'ENGW1102 , ENGW1111 , ENGW1113 , ENGW1114',
#  'AFCS2690': 'ENGW1102 , ENGW1111 , ENGW1113 , ENGW1114',
#  'AFCS3404': 'ENGW1102 , ENGW1111 , ENGW1113 , ENGW1114',
#  'AFCS3664': 'ENGW1102 , ENGW1111 , ENGW1113 , ENGW1114',
#  'AFCS4526': 'SOCL1101 , ANTH1101 , CRIM1100 , HUSV1101 , WMNS1103 , POLS1160',
#  'AFCS4588': 'ENGW1102 , ENGW1111 , ENGW1113 , ENGW1114',
#  'AMSL1102': 'AMSL1101',
#  'AMSL1511': 'AMSL1101',
#  'AMSL1512': 'AMSL1102',
#  'AMSL2101': 'AMSL1102 , DEAF1500',
#  'AMSL2102': 'AMSL2101',
#  'AMSL3101': 'AMSL2102',
#  'AMSL3102': 'AMSL3101',
#  'ALY2010': 'MTH1100 , MTH10 , MTH2100',
#  'ALY2100': 'MTH2400 , PHL2310 , ITC2300',
#  'ALY3015': 'ALY10',
#  'ALY3040': 'ALY2100 , ALY3015',
#  'ALY3070': 'ALY2100 , ALY3015',
#  'ALY3110': 'ALY2100 , ALY3015',
#  'ALY4000': 'ALY10 , ITC2300',
#  'ALY4020': 'ALY2100 , ALY3015 , ALY3040',
#  'ALY4850': 'ALY3040 , ALY3070 , ALY4000',
#  'ALY6010': 'ALY6000',
#  'ALY6015': 'ALY6000 , ALY6010',
#  'ALY6020': 'ALY6015 , ALY6070',
#  'ALY6030': 'ALY6000 , ALY6015',
#  'ALY6040': 'ALY6000 , ALY6010 , EAI6000 , EAI6010',
#  'ALY6050': 'ALY6000 , ALY6010',
#  'ALY6070': 'ALY6000 , ALY6010',
#  'ALY6080': 'ALY6015 , ALY6050 , ALY6070',
#  'ALY6110': 'ALY6000 , ALY6010 , EAI6000 , EAI6010',
#  'ALY6150': 'ALY6000 , ALY6010 , EAI6000 , EAI6010',
#  'ALY6160': 'ALY6000 , ALY6010',
#  'ALY6980': 'ALY6080 , ALY6040 , ALY6110 , ALY60 , ALY6060 , ALY61 , EAI6000 , EAI6010 , ALY6000 , ALY6010 , ALY6015 , ALY6050 , ALY6070',
#  'ALY6983': 'ALY6000 , ALY6010',
#  'ANTH2302': 'ANTH1101 , SOCL1101',
#  'ANTH2485': 'ANTH1101 , CRIM1100 , HUSV1101 , INTL1101 , POLS1160 , SOCL1101 , WMNS1103',
#  'ANTH3410': 'ANTH1101',
#  'ANTH3417': 'SOCL1101 , ANTH1101 , HUSV1101 , CRIM1100 , INTL1101 , WMNS1103 , POLS1160',
#  'ANTH3418': 'SOCL1101 , ANTH1101 , HUSV1101 , CRIM1100 , INTL1101 , WMNS1103 , POLS1160',
#  'ANTH3421': 'ANTH1101',
#  'ANTH3441': 'ANTH1101 , SOCL1101',
#  'ANTH3442': 'ANTH1101 , SOCL1101',
#  'ANTH4100': 'ANTH1101',
#  'ANTH4200': 'ANTH1101 , CRIM1100 , HUSV1101 , INTL1101 , POLS1160 , SOCL1101 , WMNS1103',
#  'ANTH4210': 'ANTH1101 , CRIM1100 , HUSV1101 , POLS1160 , SOCL1101 , WMNS1103',
#  'ANTH4220': 'ANTH1101 , CRIM1100 , HUSV1101 , INTL1101 , POLS1160 , SOCL1101 , WMNS1103',
#  'ANTH4350': 'SOCL1101 , ANTH1101 , HUSV1101 , CRIM1100 , INTL1101 , WMNS1103 , POLS1160',
#  'ANTH4410': 'ANTH1101 , CRIM1100 , HUSV1101 , INTL1101 , POLS1160 , SOCL1101 , WMNS1103',
#  'ANTH4500': 'SOCL1101 , ANTH1101 , HUSV1101 , CRIM1100 , INTL1101 , WMNS1103 , POLS1160 , ENGW1111 , ENGW1102',
#  'ANTH4510': 'ANTH1101 , CRIM1100 , HUSV1101 , INTL1101 , POLS1160 , SOCL1101 , WMNS1103 , ENGW1102 , ENGW1111 , ENGW1113 , ENGW1114',
#  'ANTH4515': 'SOCL1101 , ANTH1101 , HUSV1101 , CRIM1100 , INTL1101 , WMNS1103 , POLS1160',
#  'ANTH4520': 'ANTH1101 , INTL1101 , POLS1160 , SOCL1101 , WMNS1103',
#  'ANTH4971': 'ANTH4970',
#  'APL6100': 'APL6000 , APL6030',
#  'ARAB1102': 'ARAB1101',
#  'ARAB2101': 'ARAB1102',
#  'ARAB2102': 'ARAB2101',
#  'ARAB3101': 'ARAB2102',
#  'ARCH1120': 'ARCH1110',
#  'ARCH2130': 'ARCH11',
#  'ARCH2140': 'ARCH2130',
#  'ARCH2240': 'ARCH1110 , ARCH2260 , ARCH6100',
#  'ARCH2310': 'ARCH1310 , ASNS1150',
#  'ARCH2320': 'ASNS1150',
#  'ARCH2330': 'ENGW1111 , ENGW1102',
#  'ARCH2340': 'ENGW1111 , ENGW1102',
#  'ARCH3170': 'ARCH2140',
#  'ARCH3210': 'ARCH2240 , CIVE2260',
#  'ARCH3450': 'ARCH1110 , ARCH11 , ARCH2130',
#  'ARCH5115': 'ARCH3170',
#  'ARCH5120': 'ARCH5115 , ARCH5115',
#  'ARCH5220': 'ARCH3210 , ARCH5210 , ARCH5210',
#  'ARCH5230': 'PHYS1151 , PHYS1141 , MATH1341 , MATH1241 , ARCH2240',
#  'ARCH6440': 'ARCH6430',
#  'ART2200': 'ART00',
#  'ARTG1290': 'ARTF1122',
#  'ARTG2242': 'ARTF1122',
#  'ARTG2250': 'ARTF1122',
#  'ARTG2252': 'ARTF1122',
#  'ARTG2400': 'ARTF2223',
#  'ARTG2401': 'ARTG2400',
#  'ARTG3100': 'ARCH2260 , ARTD00 , ARTF1124 , ARTG2260 , CS2510 , GE1502',
#  'ARTG3250': 'ARTG2400',
#  'ARTG3350': 'ARTG1290 , ARTG1291 , ARTG2250',
#  'ARTG3400': 'ARTG2400',
#  'ARTG3444': 'ARTG2242',
#  'ARTG3450': 'ARTG2252',
#  'ARTG3451': 'ARTG3350',
#  'ARTG3452': 'ARTG2252',
#  'ARTG3460': 'ARTG2250',
#  'ARTG3462': 'ARTG1250 , ARTF2223',
#  'ARTG3463': 'ARTG3462',
#  'ARTG3464': 'ARTG3462',
#  'ARTG3700': 'ARTG2400',
#  'ARTG4554': 'ARTG3350',
#  'ARTG4555': 'ARTG3450 , ARTG3350',
#  'ARTG5151': 'ARTG5150 , ARTG5150',
#  'ARTG5430': 'ARTG5330 , ARTG5330',
#  'ARTG6100': 'ARTG5100 , ARTG5100',
#  'ARTG6110': 'ARTG5100',
#  'ARTG6600': 'ARTG5600',
#  'ARTG6700': 'ARTG6100 , ARTG6600',
#  'ARTG7890': 'ARTG6100',
#  'ARTG7910': 'ARTG7990',
#  'ARTF1123': 'ARTF1122',
#  'ARTF1221': 'ARTF12',
#  'ARTE2301': 'ENGW1111 , ENGW1102',
#  'ARTE7996': 'ARTE7990',
#  'ARTH2210': 'ENGW1111 , ENGW1102',
#  'ARTH2211': 'ENGW1111 , ENGW1102',
#  'ARTD2100': 'ENGW1111 , ENGW1102',
#  'ARTD2370': 'ARTF22',
#  'ARTD2380': 'ARTF22',
#  'ARTD3000': 'ARTD00 , ARTD2360 , ARTD2370 , ARTD2380',
#  'ARTD3460': 'ARTD2360',
#  'ARTD3470': 'ARTD2370',
#  'ARTD3471': 'ARTF11 , ARTD2370',
#  'ARTD3472': 'ARTF11 , ARTD2370',
#  'ARTD3473': 'ARTD3470',
#  'ARTD3480': 'ARTD2380 , MSCR1230',
#  'ARTD3485': 'ARTD2380 , MSCR1230',
#  'ARTD4565': 'ARTD3460',
#  'ARTD4570': 'ARTD3470',
#  'ARTD4575': 'ARTD4570',
#  'ARTD4660': 'ARTD2360',
#  'ARTD4661': 'ARTD2360',
#  'ARTS3000': 'ARTF11 , ARTF1121 , ARTF1122',
#  'ASNS3100': 'ENGW1102 , ENGW1111 , ENGW1113 , ENGW1114',
#  'ASNS3485': 'POLS1155',
#  'ASNS4220': 'ANTH1101 , CRIM1100 , HUSV1101 , INTL1101 , POLS1160 , SOCL1101 , WMNS1103',
#  'BNSC4900': 'BIOL4991 , BNSC4991 , BNSC4994 , PSYC4991 , ENGW3307 , ENGW3315 , ENGW3302',
#  'BNSC4971': 'BNSC4970 , BNSC4991',
#  'BIOC4900': 'BIOC4991 , BIOC4994 , BIOL4991 , CHEM4991 , ENGW3302 , ENGW3307 , ENGW3315',
#  'BIOC4971': 'BIOC4970 , BIOC4991 , BIOL4970 , BIOL4991 , CHEM4750 , CHEM4901 , CHEM4970 , ENGW3302 , ENGW3307 , ENGW3315',
#  'BIOE2350': 'MATH1252 , MATH1342 , PHYS1151 , PHYS1161 , PHYS1171',
#  'BIOE2355': 'MATH2341 , CHEM1151 , CHEM1161 , CHEM1211 , PHYS1155 , PHYS1165 , PHYS1175',
#  'BIOE2365': 'BIOL1107 , BIOL1111 , MATH1252 , MATH1342 , ENGW1111 , ENGW1102',
#  'BIOE3210': 'MATH2321 , MATH2341 , PHYS1155 , PHYS1165 , PHYS1175',
#  'BIOE3310': 'BIOE2350 , BIOE2355 , MATH2321 , MATH2341',
#  'BIOE3380': 'MATH2321 , MATH2341 , BIOE2355',
#  'BIOE3410': 'BIOE2365 , BIOE2366',
#  'BIOE4792': 'BIOE4790',
#  'BIOE4971': 'BIOE4970',
#  'BIOE5115': 'MATH2341',
#  'BIOE5235': 'BIOE3210',
#  'BIOE5410': 'BIOL1111 , MATH1342',
#  'BIOE5420': 'BIOE2355',
#  'BIOE5430': 'BIOE2355',
#  'BIOE5440': 'BIOE3380 , BIOE2350 , ME2355',
#  'BIOE5450': 'BIOE54 , BIOE54 , BIOE5430 , BIOE5430',
#  'BIOE5630': 'BIOE3310 , ME3475 , ME3480',
#  'BIOE5648': 'BIOE3210 , EECE2150',
#  'BIOE5650': 'BIOE2355 , MATH2341',
#  'BIOE5660': 'BIOE2350',
#  'BIOE5710': 'BIOE2355',
#  'BIOE5720': 'BIOE2365 , BIOE3380',
#  'BIOE5750': 'MATH2321 , MATH2341 , BIOE2365 , CHME3315 , CHME4315',
#  'BIOE5800': 'BIOE3210',
#  'BIOE5810': 'BIOE2365 , BIOE3210',
#  'BIOE5820': 'CHEM1151 , CHEM1161 , CHEM1211',
#  'BIOE5850': 'BIOE58 , BIOE58',
#  'BIOE5860': 'MATH2341 , MATH2331',
#  'BIOE5870': 'BIOE5860',
#  'BIOE5880': 'BIOE3380',
#  'BIOE9990': 'BIOE9000',
#  'BIOE9991': 'BIOE9990',
#  'BIOE9996': 'BIOE9991',
#  'BINF6250': 'BINF60 , BINF60',
#  'BINF6309': 'BINF6308 , BINF6308',
#  'BINF6310': 'BINF60 , BINF60 , DS2500',
#  'BINF6400': 'BINF60 , BINF60 , BINF6310 , BINF6310 , BINF6308 , BINF6308 , BINF6309 , BINF6309',
#  'BINF6420': 'BINF6310 , BINF6310 , BINF60 , BINF60 , BINF6308 , BINF6308 , BINF6309 , BINF6309',
#  'BINF6430': 'BINF6310 , BINF6310 , BINF60 , BINF60 , BINF6308 , BINF6308 , BINF6309 , BINF6309',
#  'BINF7700': 'BINF60 , BINF60 , BINF6310 , BINF6310 , MATH7340',
#  'BIOL1112': 'BIOL1111',
#  'BIOL1113': 'BIOL1107 , BIOL1111',
#  'BIOL1114': 'BIOL1113',
#  'BIOL2219': 'BIOL2217',
#  'BIOL2299': 'BIOL1107 , BIOL1111',
#  'BIOL2301': 'BIOL1111 , BIOL2299 , EEMB1105 , EEMB2400 , CHEM1211 , CHEM1151 , CHEM1161',
#  'BIOL2302': 'BIOL2301',
#  'BIOL2307': 'BIOL2299',
#  'BIOL2309': 'BIOL2301',
#  'BIOL2327': 'BIOL1107 , BIOL1111',
#  'BIOL2329': 'BIOL1107 , BIOL1111 , BIOL2299',
#  'BIOL3401': 'BIOL1113 , BIOL2299',
#  'BIOL3405': 'BIOL1113 , BIOL2299 , PSYC3458',
#  'BIOL3409': 'BIOL2301',
#  'BIOL3411': 'BIOL2301',
#  'BIOL3413': 'BIOL1113 , BIOL2299 , EEMB2400',
#  'BIOL3415': 'BIOL2301',
#  'BIOL3419': 'BIOL2301',
#  'BIOL3421': 'BIOL2301',
#  'BIOL3423': 'BIOL2301',
#  'BIOL3601': 'BIOL3405 , PSYC3458',
#  'BIOL3603': 'BIOL2301',
#  'BIOL3605': 'BIOL2301',
#  'BIOL3607': 'BIOL2301',
#  'BIOL3611': 'BIOL2301 , CHEM2313 , CHEM2317',
#  'BIOL4701': 'ENGW3307 , ENGW3315 , ENGW3302',
#  'BIOL4705': 'BIOL3405 , PSYC3458',
#  'BIOL4707': 'BIOL3611',
#  'BIOL4709': 'PSYC3458 , BIOL3405',
#  'BIOL4900': 'ENGW3307 , ENGW3315 , BIOL4991 , BIOL4994',
#  'BIOL4971': 'ENGW3307 , BIOL4970 , BIOL4991',
#  'BIOL5301': 'BIOL2301',
#  'BIOL5306': 'BIOL2301',
#  'BIOL5535': 'BIOL2301',
#  'BIOL5539': 'BIOL2301',
#  'BIOL5541': 'BIOL3405 , BIOL3611 , BIOL4707',
#  'BIOL5543': 'BIOL2301',
#  'BIOL5573': 'BIOL2301',
#  'BIOL5581': 'BIOL2301',
#  'BIOL5583': 'BIOL3611',
#  'BIOL5585': 'BIOL2301',
#  'BIOL5591': 'BIOL2301',
#  'BIOL5593': 'BIOL2301',
#  'BIOL5595': 'BIOL2301 , PSYC3458 , BIOL3405',
#  'BIOL5597': 'BIOL2301',
#  'BIOL5601': 'BIOL2301 , PSYC3458 , BIOL3405',
#  'BIOL6301': 'BIOL6300',
#  'BIOL9990': 'BIOL9000',
#  'BIOL9991': 'BIOL9990',
#  'BIOL9996': 'BIOL9991',
#  'BIO1200': 'BIO1100 , BIO1101',
#  'BIO1201': 'BIO1100 , BIO1101',
#  'BIO1600': 'BIO10 , BIO11',
#  'BIO1601': 'BIO10 , BIO11',
#  'BIO1700': 'BIO1600 , BIO1601',
#  'BIO1701': 'BIO1600 , BIO1601',
#  'BIO2100': 'BIO10 , BIO11',
#  'BIO2101': 'BIO10 , BIO11',
#  'BIO2300': 'BIO10 , BIO11',
#  'BIO2500': 'BIO10 , BIO11',
#  'BIO2501': 'BIO10 , BIO11',
#  'BIO3100': 'BIO10 , BIO11',
#  'BIO3101': 'BIO10 , BIO11',
#  'BIO4215': 'BIO10 , BIO11',
#  'BIOT5225': 'BIOT5219',
#  'BIOT5227': 'BIOT5219',
#  'BIOT5228': 'BIOT5219 , BIOT5219 , BIOT5219',
#  'BIOT5640': 'BIOT5621 , BIOT5621 , CHEM56 , CHEM56',
#  'BIOT5700': 'BIOT5621 , BIOT5621 , CHEM56 , CHEM56',
#  'BIOT7001': 'BIOT5219 , BIOT5219 , BIOT5219 , BIOT6500',
#  'BTC1300': 'BIO10 , BIO11',
#  'BTC1301': 'BIO10 , BIO11',
#  'BTC3210': 'BIO1100 , BIO1101 , BIO10 , BIO11',
#  'BTC4300': 'BTC1300 , BIO2300',
#  'BTC4301': 'BTC1301 , BIO2300',
#  'BTC4450': 'BTC1300 , MTH2300 , MTH2310 , MTH3300',
#  'BTC4850': 'BIO2300 , BIO2500',
#  'BTC6211': 'BTC6210 , RGA6000 , RGA6001',
#  'BTC6213': 'BTC6210 , RGA6000 , RGA6001',
#  'BUSN3501': 'FINA21 , INNO2301 , MKTG21',
#  'EXSC5200': 'BIOL2217 , BIOL2219 , EXSC4500',
#  'EXSC5220': 'EXSC4500',
#  'EXSC5230': 'EXSC4500',
#  'EXSC6300': 'EXSC50 , EXSC50 , EXSC5210 , EXSC5210 , EXSC52 , EXSC52',
#  'CHME2308': 'CHEM1151 , CHEM1161 , CHEM1211',
#  'CHME2310': 'MATH2321 , CHME2308 , MATH2341',
#  'CHME2320': 'CHME2308 , MATH2321',
#  'CHME2322': 'MATH2321 , CHME2308',
#  'CHME3305': 'CHME2310 , CHME23 , CHME2322 , ENGW3302 , ENGW3315',
#  'CHME3312': 'CHME2310 , MATH2341',
#  'CHME3315': 'CHME2310 , ENGW3302 , ENGW3315',
#  'CHME3322': 'CHME23 , CHME2322',
#  'CHME4315': 'CHME3312 , CHME3315 , CS2510 , ENGW1111',
#  'CHME4510': 'CHME3312 , CHME3322',
#  'CHME4512': 'CHME3312 , CHME3322',
#  'CHME4625': 'CHME23 , CHME2322',
#  'CHME4626': 'CHME2322 , CHME23',
#  'CHME4701': 'CHME3312 , CHME3322 , CHME4510',
#  'CHME4703': 'CHME3305 , CHME4315 , CHME4701 , CHME4512 , PHYS3600',
#  'CHME4991': 'CHME3315',
#  'CHME5137': 'CHME3312 , CHME3322',
#  'CHME5621': 'MATH2321 , MATH2341',
#  'CHME5630': 'CHME3312 , BIOE3310 , BIOE3380',
#  'CHME5642': 'CHEM1151 , CHEM1161',
#  'CHME5643': 'CHEM1151 , CHEM1161',
#  'CHME5649': 'MATH1341 , MATH1342 , MATH2321 , MATH2341',
#  'CHME7320': 'CHME4510 , CHME5101 , CHME5101',
#  'CHME7330': 'CHME3322 , CHME5101 , CHME5101',
#  'CHME7340': 'CHME4510 , CHME5101 , CHME5101',
#  'CHME7350': 'CHME3312 , CHME5101 , CHME5101',
#  'CHME7601': 'CHME7600',
#  'CHME7602': 'CHME7601',
#  'CHME9990': 'CHME9000',
#  'CHME9991': 'CHME9990',
#  'CHME9996': 'CHME9990',
#  'CHEM1214': 'CHEM1211',
#  'CHEM2117': 'CHEM1161 , CHEM1162',
#  'CHEM2161': 'CHEM1161',
#  'CHEM2311': 'CHEM1151 , CHEM1214 , CHEM1161',
#  'CHEM2313': 'CHEM2311 , CHEM2315',
#  'CHEM2315': 'CHEM1161 , CHEM1214',
#  'CHEM2317': 'CHEM2311 , CHEM2315',
#  'CHEM2321': 'CHEM1151 , CHEM1214 , CHEM1161 , CHEM2311 , CHEM2315',
#  'CHEM3100': 'CHEM2313 , CHEM2317',
#  'CHEM3331': 'CHEM1151 , CHEM1161 , CHEM1214 , CHEM2313 , CHEM2317 , CHEM2321 , BIOL3611 , ENGW1102 , ENGW1111 , ENGW1113 , ENGW1114',
#  'CHEM3401': 'MATH1252 , MATH1342 , CHEM1214 , CHEM1151 , CHEM1161 , PHYS1151 , PHYS1161',
#  'CHEM3403': 'CHEM3401 , CHEM3431 , CHME3322 , MATH1342 , PHYS1155 , PHYS1165',
#  'CHEM3410': 'CHEM1151 , CHEM1161 , CHEM1214',
#  'CHEM3431': 'CHEM1214 , CHEM1151 , CHEM1161 , MATH1252 , MATH1342 , PHYS1147 , PHYS1155 , PHYS1165 , PHYS1175',
#  'CHEM3501': 'CHEM2313 , CHEM2317 , CHEM2321 , CHEM3331',
#  'CHEM3505': 'CHEM2313 , CHEM2317 , CHEM2321 , CHEM3331',
#  'CHEM3531': 'CHEM2313 , CHEM2317 , CHEM2321 , CHEM3331',
#  'CHEM4456': 'CHEM2313 , CHEM2317',
#  'CHEM4628': 'CHEM2313 , CHEM2317',
#  'CHEM4629': 'CHEM2313 , CHEM2317',
#  'CHEM4750': 'CHEM2313 , CHEM2317',
#  'CHEM4901': 'CHEM2313 , CHEM2317 , CHEM2321',
#  'CHEM4971': 'CHEM4970',
#  'CHEM5600': 'CHEM5599',
#  'CHEM5610': 'CHEM2317 , CHEM2313 , CHEM3401 , CHEM3431',
#  'CHEM5620': 'CHEM2313 , CHEM2317',
#  'CHEM5621': 'CHEM2313 , CHEM2317 , CHEM2321 , CHEM3331 , CHEM3401 , CHEM3431',
#  'CHEM5622': 'CHEM2313 , CHEM2317 , CHEM2321 , CHEM3331 , CHEM3401 , CHEM3431 , ENGW1111 , ENGW1102 , ENGW1113 , ENGW1114',
#  'CHEM5625': 'CHEM2317 , CHEM2313 , CHEM56 , CHEM56 , CHEM5621 , CHEM5621',
#  'CHEM5628': 'CHEM2313 , CHEM2317',
#  'CHEM5636': 'CHEM3401 , CHEM3431',
#  'CHEM5642': 'CHEM1151 , CHEM1161',
#  'CHEM5649': 'MATH1341 , MATH1342 , MATH2321 , MATH2341',
#  'CHEM5651': 'CHEM2313 , CHEM2317 , CHEM3403',
#  'CHEM5653': 'CHEM5614 , CHEM5614 , CHEM5651 , CHEM5651',
#  'CHEM5672': 'CHEM5626 , CHEM5626',
#  'CHEM5676': 'CHEM5626 , CHEM5627',
#  'CHEM9990': 'CHEM9000',
#  'CHEM9991': 'CHEM9990',
#  'CHEM9996': 'CHEM9991',
#  'CHM1200': 'CHM1100 , CHM1101',
#  'CHM1201': 'CHM1100 , CHM1101',
#  'CHM2110': 'CHM10 , CHM11',
#  'CHM2111': 'CHM10 , CHM11',
#  'CHM2200': 'CHM2110 , CHM2111',
#  'CHM2201': 'CHM2110 , CHM2111',
#  'CHM2300': 'CHM10 , CHM11',
#  'CHM2301': 'CHM10 , CHM11',
#  'CHNS1102': 'CHNS1101',
#  'CHNS2101': 'CHNS1102',
#  'CHNS2102': 'CHNS2101 , CHNS2301',
#  'CHNS3101': 'CHNS2102 , CHNS2302',
#  'CHNS3102': 'CHNS3101 , CHNS3301',
#  'CIVE2221': 'MATH1342 , PHYS1151 , PHYS1161 , PHYS1141 , MATH1241',
#  'CIVE2260': 'CHEM1151 , CHEM1161 , CHEM1211 , MATH1342 , PHYS1151 , PHYS1161',
#  'CIVE2300': 'CHEM1151 , CHEM1161 , CHEM1211',
#  'CIVE2320': 'CIVE2221',
#  'CIVE2324': 'CIVE2221',
#  'CIVE2331': 'CIVE2221',
#  'CIVE2334': 'CHEM1151 , CHEM1161 , CHEM1211',
#  'CIVE2335': 'CHEM1151 , CHEM1161 , CHEM1211',
#  'CIVE2340': 'CIVE2221 , CIVE2260',
#  'CIVE3335': 'CHEM1151 , CHEM1161 , CHEM1211',
#  'CIVE3425': 'CIVE23',
#  'CIVE3430': 'CHEM1151 , CHEM1161 , CHEM1211',
#  'CIVE3435': 'CHEM1151 , CHEM1161 , CHEM1214',
#  'CIVE3464': 'MATH2321',
#  'CIVE4534': 'CIVE2331 , CHME2310 , CIVE2334',
#  'CIVE4542': 'CIVE2340 , ENGW1111 , ENGW1102',
#  'CIVE4554': 'CIVE2261 , ENGW1111 , ENGW1102',
#  'CIVE4765': 'CIVE5536 , CIVE4534 , ENGW3302 , ENGW3315',
#  'CIVE4767': 'CIVE2324 , CIVE3425 , CIVE2324 , CIVE5522 , CIVE3425 , CIVE5522 , CIVE2324 , CIVE3425 , CIVE4542 , CS3000 , ENGW3302 , ENGW3315',
#  'CIVE4768': 'CIVE4554 , ENGW3302 , ENGW3315 , CIVE5373 , CIVE5376 , CS3000',
#  'CIVE4780': 'CIVE2221 , ME2350 , ARCH2240',
#  'CIVE4971': 'CIVE4970',
#  'CIVE5150': 'ENVR10 , ENVR20 , PHYS1151 , PHYS1152 , PHYS1153',
#  'CIVE5221': 'CIVE4575 , CIVE72',
#  'CIVE5231': 'CIVE4575 , CIVE72',
#  'CIVE5232': 'CIVE4575',
#  'CIVE5250': 'CHEM1151 , CHEM1211',
#  'CIVE5281': 'CIVE2331',
#  'CIVE5300': 'CHEM1151 , CHEM1161 , CHEM1211',
#  'CIVE5369': 'CIVE2331 , MATH2321 , PHYS1161',
#  'CIVE5520': 'CIVE23',
#  'CIVE5522': 'CIVE23 , MATH2341',
#  'CIVE5524': 'CIVE23 , MATH2341',
#  'CIVE5527': 'CIVE2324 , CIVE3425',
#  'CIVE5536': 'CIVE2331 , ENGW1111 , ENGW1102',
#  'CIVE7155': 'MATH2341',
#  'CIVE7278': 'CIVE5366',
#  'CIVE7279': 'CIVE5366 , CIVE7278',
#  'CIVE7281': 'CIVE5281 , CIVE5281',
#  'CIVE7282': 'CIVE5281 , CIVE5281 , CHME7350',
#  'CIVE7313': 'CIVE7301',
#  'CIVE7340': 'CIVE7331',
#  'CIVE7355': 'CIVE5525',
#  'CIVE7383': 'CIVE7281',
#  'CIVE9990': 'CIVE9000',
#  'CIVE9991': 'CIVE9990',
#  'CIVE9996': 'CIVE9991',
#  'CED6010': 'CED6050',
#  'CED6011': 'CED6010',
#  'CED6020': 'CED6050',
#  'CED6021': 'CED60',
#  'CED6031': 'CED6030',
#  'CED6040': 'CED6030',
#  'CED6041': 'CED6030 , CED6040',
#  'CED6051': 'CED6050',
#  'CED6910': 'CED6010 , CED60 , CED6030 , CED6040 , CED6050',
#  'COMM3200': 'ENGW1111 , ENGW1102',
#  'COMM3201': 'ENGW1111 , ENGW1102',
#  'COMM3230': 'ENGW1111 , ENGW1102',
#  'COMM3304': 'ENGW1111 , ENGW1102',
#  'COMM3320': 'ENGW1111 , ENGW1102',
#  'COMM3409': 'ENGW1111 , ENGW1102 , COMM1210 , COMM1225 , COMM1231 , COMM1255 , COMM1331 , COMM1412',
#  'COMM3415': 'ENGW1111 , ENGW1102',
#  'COMM3500': 'ENGW1111 , ENGW1102',
#  'COMM3501': 'ENGW1111 , ENGW1102',
#  'COMM3530': 'ENGW1111 , ENGW1102',
#  'COMM3532': 'ENGW1111 , ENGW1102',
#  'COMM4102': 'COMM2301',
#  'COMM4533': 'ENGW1102 , ENGW1111',
#  'COMM4535': 'ENGW1111 , ENGW1102',
#  'COMM4605': 'ENGW1111 , ENGW1102',
#  'COMM4631': 'ENGW1111 , ENGW1102',
#  'COMM4992': 'COMM1101',
#  'COMM4994': 'COMM1101',
#  'COMM6995': 'COMM5250',
#  'CMN2310': 'ENG1105',
#  'CMN3100': 'CMN1100',
#  'CMN3220': 'CMN1100',
#  'CMN3350': 'CMN1100',
#  'CMN3360': 'CMN1100 , CMN2310',
#  'CMN3800': 'MKT3010',
#  'CMN3850': 'CMN3800',
#  'CMN4850': 'CMN3800',
#  'CMN6010': 'CMN6000',
#  'CMN6065': 'CMN6045',
#  'CMN6075': 'CMN6910',
#  'CMN6910': 'CMN6010',
#  'CMN6940': 'CMN60 , CMN6910',
#  'CET2200': 'ALY2100 , GET2100 , ITC2100',
#  'CET3100': 'CET2100 , GET2100',
#  'CET4210': 'CET2100 , EET3100 , EET3300',
#  'CS1210': 'CS2510 , DS2500',
#  'CS2510': 'CS2500',
#  'CS2800': 'CS1800 , MATH1365 , CS2500',
#  'CS2810': 'CS1800 , CS2500',
#  'CS3000': 'CS2510 , DS2500 , CS1800 , EECE2160',
#  'CS3200': 'CS2500 , DS00 , EECE2560',
#  'CS3500': 'CS2510 , EECE2560',
#  'CS3520': 'CS2510 , DS2500',
#  'CS3540': 'CS2500 , ARTG2260 , ARTG2262',
#  'CS3620': 'CS2510 , ENGW1111 , ENGW1102',
#  'CS3650': 'CS2510 , EECE2560',
#  'CS3700': 'CS2510',
#  'CS3800': 'CS2510 , EECE2160',
#  'CS3950': 'CS2500',
#  'CS4097': 'CS3540',
#  'CS4100': 'CS3500 , DS3500',
#  'CS4120': 'CS3500 , DS3500',
#  'CS4150': 'CS3500 , CS35',
#  'CS4180': 'CS3000 , ECON2350 , ENVR2500 , MATH3081 , PSYC23 , CS2810 , MATH2331 , CS2810',
#  'CS4300': 'CS2510 , CS3500 , EECE2560 , MATH1260 , MATH2331 , MATH2341 , CS2810',
#  'CS4360': 'CS2810 , MATH2331 , CS3500',
#  'CS4400': 'CS3500 , CS3000',
#  'CS4410': 'CS4400 , CS5400 , CS7400',
#  'CS4500': 'CS3500 , ENGW1111 , ENGW1102',
#  'CS4520': 'CS3500',
#  'CS4530': 'CS3500',
#  'CS4550': 'CS3500 , DS3500',
#  'CS4610': 'CS3500',
#  'CS4700': 'CS3650 , CS5600 , CS5600',
#  'CS4710': 'CS3700 , CS4730',
#  'CS4730': 'CS3650',
#  'CS4805': 'CS3800',
#  'CS4810': 'CS3000',
#  'CS4820': 'CS2800 , CS3000',
#  'CS4830': 'CS3000',
#  'CS4850': 'CS35 , CS3540',
#  'CS4950': 'CS3950',
#  'CS4955': 'CS2500',
#  'CS4971': 'CS4970',
#  'CS4973': 'CS3000 , CS3500 , DS3500',
#  'CS4991': 'CS3500 , CS3800',
#  'CS4992': 'CS3500 , CS3800',
#  'CS5004': 'CS5001 , CS5001 , CS5002 , CS5002',
#  'CS5008': 'CS5001 , CS5001 , CS5002 , CS5002',
#  'CS5170': 'CS5100 , CS5800 , CS6140',
#  'CS5310': 'MATH2331',
#  'CS5330': 'MATH2331',
#  'CS5400': 'CS5010 , CS5004 , CS5010',
#  'CS5500': 'CS5010 , CS5004 , CS5010',
#  'CS5540': 'CS5004 , CS5004 , CS2500 , CS2510 , CS3500 , CS5010',
#  'CS6140': 'CS5800 , CS7800',
#  'CS6220': 'CS5800 , CS7800',
#  'CS6240': 'CS5800 , CS7800 , EECE75',
#  'CS6410': 'CS5400 , CS7400',
#  'CS6510': 'CS5004 , CS5010 , CS5500',
#  'CS6640': 'CS3650 , CS5600',
#  'CS6710': 'CS5700 , CS5700',
#  'CS7140': 'CS6140 , EECE74',
#  'CS7150': 'CS6140 , DS52',
#  'CS7170': 'CS5100 , CS5100',
#  'CS7270': 'CS50 , CS50',
#  'CS7332': 'PHYS5116',
#  'CS7470': 'CS5400 , CS5400 , CS7400',
#  'CS7670': 'CS5600 , CS5600 , CS7600',
#  'CS7770': 'CS5700 , CS5700',
#  'CS7805': 'CS7800',
#  'CS7870': 'CS5800 , CS5800 , CS7800',
#  'CS7980': 'CS5004 , CS5010 , CS5800',
#  'CS7996': 'CS7990',
#  'CS9990': 'CS9000',
#  'CS9991': 'CS9990',
#  'CS9996': 'CS9991',
#  'CSYE6220': 'CSYE60 , CSYE62 , CSYE65',
#  'CSYE6225': 'CSYE60 , INFO5100 , INFO5100',
#  'CSYE6230': 'INFO65',
#  'CSYE6305': 'INFO65',
#  'CSYE7105': 'DAMG6105 , INFO6105',
#  'CSYE7125': 'CSYE6225',
#  'CSYE7215': 'CSYE60 , INFO5100 , INFO5100',
#  'CSYE7220': 'CSYE62 , INFO6250',
#  'CSYE7230': 'CSYE60 , INFO5100 , INFO5100',
#  'CSYE7235': 'INFO65',
#  'CSYE7280': 'CSYE60 , INFO5100 , INFO5100',
#  'CSYE7370': 'INFO5100 , INFO5100 , CSYE60',
#  'CSYE7380': 'INFO65',
#  'CSYE7470': 'INFO6105',
#  'CSYE7550': 'CSYE7270 , INFO65',
#  'INNO4504': 'INNO2301',
#  'INNO6241': 'INNO6240',
#  'INNO6242': 'INNO6241',
#  'CAEP4505': 'BIOL1113 , BIOL1147 , CAEP12',
#  'CAEP6242': 'CAEP60',
#  'CAEP6283': 'CAEP60',
#  'CAEP6286': 'CAEP60',
#  'CAEP6324': 'CAEP6331',
#  'CAEP6327': 'CAEP6326 , CAEP6326 , CAEP6326 , CAEP6329 , CAEP6329 , CAEP6329',
#  'CAEP6331': 'CAEP6326 , CAEP6326 , CAEP6326 , CAEP6328 , CAEP6328 , CAEP6328',
#  'CAEP6332': 'CAEP6331 , CAEP6331',
#  'CAEP6334': 'CAEP6327 , CAEP6327 , CAEP6327',
#  'CAEP6335': 'CAEP6334',
#  'CAEP6336': 'CAEP6331 , CAEP6331 , CAEP6334',
#  'CAEP6341': 'CAEP6326 , CAEP6329',
#  'CAEP6343': 'CAEP6326',
#  'CAEP6344': 'CAEP6326 , CAEP6328',
#  'CAEP6349': 'CAEP6348',
#  'CAEP6360': 'CAEP6347',
#  'CAEP6375': 'CAEP60',
#  'CAEP6394': 'CAEP63',
#  'CAEP6402': 'CAEP6401',
#  'CAEP7413': 'CAEP7412',
#  'CAEP7742': 'CAEP7741',
#  'CAEP7743': 'CAEP7742 , CAEP7742',
#  'CAEP7744': 'CAEP7743',
#  'CAEP8401': 'CAEP6399',
#  'CAEP8412': 'CAEP6341',
#  'CAEP8413': 'CAEP6342',
#  'CAEP8416': 'CAEP8415',
#  'CAEP8418': 'CAEP8417',
#  'CAEP8553': 'CAEP7744',
#  'CAEP9990': 'CAEP9000',
#  'CAEP9991': 'CAEP9990',
#  'CAEP9996': 'CAEP9991',
#  'CRIM2380': 'ENGW1102 , ENGW1111 , ENGW1113 , ENGW1114',
#  'CRIM3000': 'EESH00',
#  'CRIM4000': 'CRIM3000',
#  'CRIM4971': 'CRIM4970',
#  'CRIM7711': 'CRIM7710',
#  'CRIM7715': 'INSH5301 , INSH6500',
#  'CRIM7716': 'CRIM7715',
#  'CRIM9990': 'CRIM9000',
#  'CRIM9991': 'CRIM9990',
#  'CRIM9996': 'CRIM9991',
#  'CLTR2451': 'ENGW1102 , ENGW1111 , ENGW1113 , ENGW1114',
#  'CLTR3240': 'SPNS2102 , SPNS3101 , SPNS3102 , SPNS3101 , SPNS3102',
#  'CLTR3418': 'POLS1155 , POLS1160',
#  'CLTR3715': 'SPNS2102 , SPNS3101 , SPNS3102',
#  'CLTR3720': 'SPNS2102 , SPNS3101 , SPNS3102',
#  'CLTR4655': 'SPNS2101 , SPNS2102 , SPNS3101 , SPNS3102',
#  'CY2550': 'CS2500 , DS00',
#  'CY3740': 'CS3650',
#  'CY4740': 'CS3700 , CS4700 , CS4730 , CS5700',
#  'CY4770': 'CS3000 , CS3800',
#  'CY4930': 'CY3740 , CY4740',
#  'CY4971': 'CY4970',
#  'CY4973': 'CS3000 , CS3500 , DS3500',
#  'CY5061': 'CY5001 , CY5010',
#  'CY5065': 'CY5010',
#  'CY5120': 'CY5001 , CY5010',
#  'CY5130': 'CY5001 , CY5010',
#  'CY5150': 'CY5001 , CY5010',
#  'CY5200': 'CY2550 , CY5010',
#  'CY5210': 'CY2550 , CY5010',
#  'CY5240': 'CY2550 , CY5010',
#  'CY5770': 'CY5001 , CY5010',
#  'CY6120': 'CY5010',
#  'CY6740': 'CY5001 , CY5010',
#  'CY9990': 'CY9000',
#  'CY9991': 'CY9990',
#  'CY9996': 'CY9991',
#  'DAMG7105': 'INFO5002 , INFO6105 , DAMG6105',
#  'DAMG7245': 'DAMG6105 , INFO6105',
#  'DAMG7250': 'CSYE60 , DAMG6105 , DAMG6210 , INFO5100',
#  'DAMG7275': 'DAMG6210',
#  'DAMG7290': 'DAMG6210 , DAMG7275 , INFO65',
#  'DAMG7325': 'DAMG6105 , DAMG6210',
#  'DAMG7350': 'DAMG6105 , DAMG6210',
#  'DAMG7370': 'DAMG6210',
#  'DAMG7390': 'DAMG7370',
#  'DAMG7990': 'DAMG7945',
#  'DS2500': 'DS00',
#  'DS3000': 'CS2510 , DS2500',
#  'DS3500': 'DS2500',
#  'DS4200': 'CS2510 , DS2500',
#  'DS4300': 'CS30 , DS3000',
#  'DS4400': 'DS3000 , CS2810 , DS3500 , CS3500',
#  'DS4420': 'DS4400',
#  'DS4440': 'DS4400',
#  'DS4971': 'DS4970',
#  'DS4973': 'CS3000 , CS3500 , DS3500',
#  'DS5500': 'CS5800 , EECE75 , DS5110 , DS52 , DS5230',
#  'DEAF1550': 'AMSL1102',
#  'DEAF2500': 'DEAF1500',
#  'DEAF2700': 'LING1150 , ENGW1111 , ENGW1102 , AMSL1102',
#  'DGM6122': 'DGM6105 , DGM6501',
#  'DGM6125': 'DGM6122',
#  'DGM6217': 'DGM6105',
#  'DGM6230': 'DGM6280',
#  'DGM6268': 'DGM6168',
#  'DGM6308': 'DGM6108 , DGM6501',
#  'DGM6322': 'DGM6122',
#  'DGM6403': 'DGM6400',
#  'DGM6405': 'DGM6403',
#  'DGM6410': 'DGM6405',
#  'DGM6435': 'DGM6506',
#  'DGM6440': 'DGM6435',
#  'DGM6450': 'DGM6105',
#  'DGM6451': 'DGM6108 , DGM6521',
#  'DGM6461': 'DGM6168 , TCC61',
#  'DGM6463': 'DGM6461 , DGM6217',
#  'DGM6471': 'DGM6461 , DGM6217',
#  'DGM6510': 'DGM6450',
#  'DGM6516': 'DGM6506',
#  'DGM6525': 'DGM6168',
#  'DGM6530': 'DGM6450',
#  'DGM6535': 'DGM6540',
#  'DGM6540': 'DGM6440 , DGM6515',
#  'DGM6545': 'DGM6440',
#  'DGM6550': 'DGM6461 , DGM6285',
#  'DGTR2199': 'DGTR1101',
#  'DGTR2850': 'DGTR1101',
#  'DGTR3000': 'DGTR1001',
#  'DGTR3100': 'DGTR1101 , DGTR2850',
#  'DGTR3199': 'DGTR2199',
#  'DGTR3299': 'DGTR2299',
#  'DGTR3310': 'DGTR1101',
#  'DGTR3500': 'IS1300 , PHIL1300',
#  'DGTR3550': 'DGTR1101',
#  'DGTR4000': 'DGTR3310',
#  'DGTR4100': 'DGTR1110',
#  'DGTR4320': 'DGTR1110',
#  'DGTR4450': 'DGTR1110 , ENGW3302',
#  'DGTR4580': 'DGTR4100',
#  'DGTR4720': 'DGTR1001 , DGTR1110',
#  'ENVR1201': 'ENVR10',
#  'ENVR2310': 'ENVR1101 , ENVR10 , ENVR1400 , ENGW1111 , ENGW1102',
#  'ENVR2340': 'ENVR10',
#  'ENVR2515': 'ENVR1101 , ENVR1400',
#  'ENVR3150': 'EEMB1101 , ENVR1101 , ENVR1110 , ENVR11 , ENVR10 , ENVR1400 , SOCL1246',
#  'ENVR3300': 'EEMB1101 , ENVR1101 , ENVR10 , ENVR1400 , ENVR20',
#  'ENVR3410': 'CHEM1151 , CHEM1161 , CHEM1214',
#  'ENVR3418': 'ENVR10 , ENVR1400 , MATH1241 , MATH1251 , MATH1341',
#  'ENVR3435': 'CHEM1151 , CHEM1161 , CHEM1214',
#  'ENVR3540': 'ENVR1101 , ENVR1400 , PSYC1101',
#  'ENVR3800': 'EEMB1101 , ENVR1101 , ENVR1400',
#  'ENVR3850': 'EEMB1101 , ENVR1101 , ENVR1400',
#  'ENVR4500': 'ENVR10 , ENVR1400 , MATH1241 , MATH1251 , MATH1341',
#  'ENVR4504': 'CHEM1161 , CHEM1214 , EEMB1101 , ENVR1101 , ENVR10 , ENVR1400',
#  'ENVR4505': 'EEMB1101 , ENVR1101 , ENVR10 , ENVR1400',
#  'ENVR4971': 'ENVR4970',
#  'ENVR5150': 'ENVR10 , ENVR20 , PHYS1151 , PHYS1152 , PHYS1153',
#  'ENVR5190': 'ENVR1101 , ENVR10 , ENVR1400 , ENVR2310',
#  'ENVR5210': 'ENGW1111 , ENGW1102',
#  'ENVR5500': 'ENVR2500',
#  'ENVR5563': 'ENVR3300 , ENVR5260 , ENVR5260',
#  'ENVR5700': 'EEMB2302 , ENVR1400',
#  'ENVR5750': 'ENVR1400 , EEMB2302',
#  'ENVR5800': 'ENVR1101 , EEMB2302',
#  'ENVR6954': 'MATH6000',
#  'EEMB2302': 'ENGW1111 , ENGW1102',
#  'EEMB2400': 'BIOL1107 , BIOL1111 , EEMB1101 , ENVR1400',
#  'EEMB2610': 'BIOL1107 , BIOL1111 , EEMB1101 , EEMB1105 , ENVR1400',
#  'EEMB2700': 'BIOL1107 , BIOL1111 , EEMB1101 , ENGW1111 , ENGW1102',
#  'EEMB3250': 'EEMB2302',
#  'EEMB3455': 'BIOL1107 , BIOL1111 , CHEM1161 , CHEM1214 , EEMB2302 , ENVR10 , ENVR20',
#  'EEMB3460': 'BIOL1107 , BIOL1111 , EEMB1101 , ENVR1101 , ENVR1400',
#  'EEMB3465': 'BIOL2301 , CS2500 , ECON2350 , EEMB2400 , ENVR2500 , MATH3081',
#  'EEMB3466': 'BIOL1107 , BIOL1111 , EEMB1101 , ENVR1101 , ENVR1400',
#  'EEMB3475': 'EEMB2302',
#  'EEMB3600': 'BIOL1113 , BIOL2299 , EEMB1105',
#  'EEMB3700': 'EEMB2302 , EEMB2303',
#  'EEMB4001': 'BIOL1107 , BIOL1111 , EEMB1101 , ENVR1101 , ENVR1400',
#  'EEMB5130': 'MATH1241 , MATH1251 , MATH1341 , ENGW1111 , ENGW1102',
#  'EEMB5504': 'EEMB2302',
#  'EEMB5506': 'EEMB2302',
#  'EEMB5508': 'EEMB2302',
#  'EEMB5510': 'EEMB2302 , EEMB2700 , EEMB3460 , EEMB3475 , EEMB4001',
#  'EEMB5512': 'EEMB2302',
#  'EEMB5518': 'EEMB2302',
#  'EEMB5520': 'EEMB2302',
#  'EEMB5522': 'EEMB2302',
#  'EEMB5525': 'ENVR2500',
#  'EEMB5528': 'EEMB2302',
#  'EEMB5542': 'EEMB2302 , EEMB2700 , EEMB3460 , EEMB4001',
#  'EEMB5546': 'EEMB2302 , EEMB2700 , EEMB3460 , EEMB4001',
#  'EEMB9990': 'EEMB9000',
#  'EEMB9991': 'EEMB9990',
#  'EEMB9996': 'EEMB9991',
#  'ECON2315': 'ECON1115 , MATH1231 , MATH1241 , MATH1242 , MATH1245 , MATH1251 , MATH1340 , MATH1341 , MATH1342',
#  'ECON2316': 'ECON1116 , MATH1231 , MATH1241 , MATH1242 , MATH1245 , MATH1251 , MATH1340 , MATH1341 , MATH1342',
#  'ECON2560': 'ECON1115 , ECON1116 , ECON2350 , MATH2280 , MATH3081 , INSH3102 , MGSC2301 , POLS2400 , PSYC23 , ENGW1111 , ENGW1102 , ENGW1113 , ENGW1114 , MATH1231 , MATH1241 , MATH1245 , MATH1251 , MATH1340 , MATH1341',
#  'ECON2990': 'ECON1115 , ECON1116',
#  'ECON3255': 'ECON1116',
#  'ECON3290': 'ECON1116 , ECON1115',
#  'ECON3291': 'ECON1116 , ECON2350 , MATH2280 , MATH3081 , MGSC2301 , POLS2400 , PSYC23',
#  'ECON3404': 'ECON1116',
#  'ECON3405': 'ECON1116',
#  'ECON3406': 'ECON1116',
#  'ECON3410': 'ECON1116 , ECON2350 , MATH2280 , MATH3081 , MGSC2301 , POLS2400 , PSYC23',
#  'ECON3412': 'ECON1116',
#  'ECON3413': 'ECON1116 , ECON2350 , MATH2280 , MATH3081 , MGSC2301 , POLS2400 , PSYC23',
#  'ECON3416': 'ECON1116 , ECON2350 , MATH2280 , MATH3081 , MGSC2301 , POLS2400 , PSYC23',
#  'ECON3420': 'ECON1116',
#  'ECON3423': 'ECON1116',
#  'ECON3424': 'ECON1116',
#  'ECON3425': 'ECON1116',
#  'ECON3440': 'ECON1116',
#  'ECON3442': 'ECON1115',
#  'ECON3460': 'ECON1116',
#  'ECON3462': 'ECON1116',
#  'ECON3470': 'ECON1115 , ENGW1111 , ENGW1102 , ENGW1113 , ENGW1114',
#  'ECON3481': 'ECON1116',
#  'ECON3490': 'ECON1115 , ECON1116',
#  'ECON3520': 'ECON1115 , ECON1116 , ENGW1102 , ENGW1111 , ENGW1113 , ENGW1114',
#  'ECON3635': 'ECON1115 , ECON1116',
#  'ECON3711': 'ECON1116',
#  'ECON3915': 'ECON1115',
#  'ECON3916': 'ECON1116',
#  'ECON3990': 'ECON2315 , ECON2316',
#  'ECON4637': 'ECON2315',
#  'ECON4640': 'ECON2315 , ECON2316 , ECON2350 , MATH2280 , MATH3081 , MGSC2301 , POLS2400 , PSYC23',
#  'ECON4680': 'ECON2316',
#  'ECON4681': 'ECON2316 , ECON2350 , MATH2280 , MATH3081 , MGSC2301 , POLS2400 , PSYC23',
#  'ECON4692': 'ECON2315 , ECON2316 , ECON2350 , MATH2280 , MATH3081 , MGSC2301 , POLS2400 , PSYC23',
#  'ECON4915': 'ECON2315',
#  'ECON4916': 'ECON2316',
#  'ECON4970': 'ECON2315 , ECON2316 , ECON2350 , MATH2280 , MATH3081 , MGSC2301 , POLS2400 , PSYC23',
#  'ECON4971': 'ECON4970',
#  'ECON4997': 'ECON2315 , ECON2316 , ECON2560',
#  'ECON5140': 'ECON5105 , ECON6105',
#  'ECON5293': 'ECON2315 , ECON2316 , ECON2560',
#  'ECON5650': 'ECON2315 , ECON2560',
#  'ECON6140': 'ECON5105 , ECON5105 , ECON6105',
#  'ECON7240': 'ECON5140 , ECON5140',
#  'ECON7266': 'ECON5110 , ECON5110',
#  'ECON7710': 'ECON6110 , ECON6110',
#  'ECON7720': 'ECON61 , ECON61',
#  'ECON7740': 'ECON6140 , ECON6140',
#  'ECON7751': 'ECON6110 , PPUA6502',
#  'ECON7763': 'ECON7710 , ECON7740',
#  'ECON7764': 'ECON7763',
#  'ECON7771': 'ECON7710 , ECON7740',
#  'ECON7772': 'ECON7771',
#  'ECON9990': 'ECON9000',
#  'ECON9991': 'ECON9990',
#  'ECON9996': 'ECON9991',
#  'EDUT6101': 'EDUT6100',
#  'EDUT6102': 'EDUT6101',
#  'EDUT6104': 'EDUT6103',
#  'EDUT6107': 'EDUT6106',
#  'EDUT6108': 'EDUT6107',
#  'EDUT6110': 'EDUT6109',
#  'EDUT6113': 'EDUT6112',
#  'EDUT6116': 'EDUT6115',
#  'EDUT6117': 'EDUT6116',
#  'EDUT6119': 'EDUT6118',
#  'EDUT6120': 'EDUT6119',
#  'EDUT6122': 'EDUT6121',
#  'EDUT6123': 'EDUT6122',
#  'EDUT6125': 'EDUT6124',
#  'EDUT6126': 'EDUT6125',
#  'EDUT6128': 'EDUT6127',
#  'EDUT6129': 'EDUT6128',
#  'EDUT6204': 'EDUT63',
#  'EDUT6209': 'EDUT68',
#  'EDUT6211': 'EDUT6210',
#  'EDUT6303': 'EDUT6302',
#  'EDU6064': 'EDU6104 , EDU6107',
#  'EDU6086': 'EDU6104 , EDU6107',
#  'EDU6122': 'EDU6104 , EDU6107',
#  'EDU6124': 'EDU6104 , EDU6107',
#  'EDU6127': 'EDU6104 , EDU6107',
#  'EDU6129': 'EDU6104 , EDU6107',
#  'EDU6154': 'EDU6104 , EDU6107',
#  'EDU6155': 'EDU6104 , EDU6107',
#  'EDU6162': 'EDU6104 , EDU6107',
#  'EDU6202': 'EDU6051 , EDU64',
#  'EDU6205': 'EDU6051',
#  'EDU6216': 'EDU65',
#  'EDU6218': 'EDU64',
#  'EDU6219': 'EDU64 , EDU6217',
#  'EDU6222': 'EDU64 , EDU6217 , EDU6051 , EDU65 , EDU6218 , EDU6234 , EDU6219',
#  'EDU6224': 'EDU6050 , EDU64',
#  'EDU6319': 'EDU6050 , EDU64',
#  'EDU6321': 'EDU6051 , EDU6319',
#  'EDU6323': 'EDU6051',
#  'EDU6324': 'EDU6051',
#  'EDU6328': 'EDU6050',
#  'EDU6329': 'EDU6050 , EDU64',
#  'EDU6330': 'EDU6050',
#  'EDU6331': 'EDU6050',
#  'EDU6332': 'EDU6050 , EDU64',
#  'EDU6334': 'EDU6050 , EDU6319',
#  'EDU6335': 'EDU6334',
#  'EDU6338': 'EDU6335',
#  'EDU6465': 'EDU6050',
#  'EDU6866': 'EDU6104',
#  'EDU6980': 'EDU6183',
#  'EDU6995': 'EDU6107 , EDU6425 , EDU6310',
#  'EDU7204': 'EDU77',
#  'EDU7213': 'EDU77',
#  'EDU7217': 'EDU77',
#  'EDU7218': 'EDU77 , EDU7225',
#  'EDU7219': 'EDU7218 , EDU7226',
#  'EDU7225': 'EDU77',
#  'EDU7226': 'EDU77 , EDU7218 , EDU7225',
#  'EDU7227': 'EDU77',
#  'EDU7228': 'EDU77',
#  'EDU7229': 'EDU77',
#  'EDU7234': 'EDU77',
#  'EDU7272': 'EDU77',
#  'EDU7275': 'EDU77',
#  'EDU7276': 'EDU77',
#  'EDU7277': 'EDU77',
#  'EDU7281': 'EDU7280',
#  'EDU7283': 'EDU7281',
#  'EDU7294': 'EDU77 , EDU7218 , EDU7219 , EDU7225 , EDU7226',
#  'EDU7295': 'EDU7294',
#  'EDU7296': 'EDU77',
#  'EDU7310': 'EDU7294',
#  'EDU7311': 'EDU77',
#  'EDU7312': 'EDU77',
#  'EDU7313': 'EDU77',
#  'EDU7314': 'EDU77',
#  'EDU7315': 'EDU77',
#  'EDU7316': 'EDU77',
#  'EDU7317': 'EDU77',
#  'EDU7501': 'EDU77',
#  'EDU7502': 'EDU77',
#  'EDU7503': 'EDU77',
#  'EDU7504': 'EDU77',
#  'EDU7510': 'EDU77',
#  'EDU7511': 'EDU77',
#  'EDU8750': 'EDU7295',
#  'EDU8792': 'EDU8791',
#  'EDU8796': 'EDU7282 , EDU7283',
#  'EDUC5504': 'EDUC1111',
#  'EDUC5570': 'EDUC1111',
#  'EECE2150': 'GE1111 , GE1502 , MATH2341 , PHYS1155 , PHYS1165 , PHYS1175 , EECE2140',
#  'EECE2160': 'GE1111 , GE1502 , EECE2140',
#  'EECE2210': 'MATH1342',
#  'EECE2300': 'GE1111 , GE1502 , CS2500',
#  'EECE2310': 'CS1800',
#  'EECE2322': 'EECE2160',
#  'EECE2412': 'EECE2150 , EECE2210 , BIOE3210',
#  'EECE2520': 'EECE2150 , EECE2210 , BIOE3210 , MATH2341',
#  'EECE2530': 'EECE2150 , EECE2210 , BIOE3210 , MATH2321 , PHYS1155 , PHYS1165 , PHYS1175',
#  'EECE2531': 'BIOE3210 , EECE2150 , EECE2210 , MATH2321 , PHYS1155 , PHYS1165 , PHYS1175',
#  'EECE2540': 'EECE2140',
#  'EECE2560': 'EECE2160',
#  'EECE3324': 'EECE2322 , EECE2323',
#  'EECE3400': 'EECE2150 , MATH2341',
#  'EECE3410': 'EECE2412',
#  'EECE3468': 'EECE2150 , MATH2341',
#  'EECE4512': 'EECE2210 , EECE2412 , BIOE3210',
#  'EECE4520': 'CS3000 , EECE2560',
#  'EECE4534': 'EECE3324 , CS3650',
#  'EECE4574': 'EECE2412',
#  'EECE4604': 'EECE2412',
#  'EECE4630': 'EECE2160 , EECE2412',
#  'EECE4632': 'EECE2322',
#  'EECE4646': 'BIOE3210 , EECE2150 , EECE2210 , PHYS1155',
#  'EECE4649': 'MATH1242 , MATH1342 , PHYS1145 , PHYS1151 , PHYS1171',
#  'EECE4694': 'MATH2341 , GE1111 , GE1502',
#  'EECE4790': 'EECE2322 , EECE2412 , EECE25 , EECE2530 , EECE2540 , EECE2560 , CS3000',
#  'EECE4791': 'EECE2322 , EECE2412 , EECE25 , EECE2530 , EECE2540 , EECE2560 , CS3000',
#  'EECE4792': 'EECE4790 , EECE4791',
#  'EECE5115': 'MATH2341',
#  'EECE5155': 'EECE2540 , CS3700',
#  'EECE5161': 'MATH1342 , PHYS1155',
#  'EECE5170': 'MATH2321 , PHYS1155 , CHEM1151 , CHEM1211',
#  'EECE5360': 'EECE2560 , CS3000',
#  'EECE5550': 'EECE25 , EECE2560 , CS3000',
#  'EECE5552': 'EECE2160 , EECE25',
#  'EECE5554': 'MATH3081 , EECE3468 , EECE2160 , EECE2210',
#  'EECE5576': 'EECE3400',
#  'EECE5580': 'EECE25',
#  'EECE5582': 'EECE3468',
#  'EECE5606': 'EECE2412',
#  'EECE5608': 'MATH2321 , PHYS1155 , PHYS1165',
#  'EECE5610': 'EECE5580 , EECE5580',
#  'EECE5612': 'EECE25 , EECE3468 , MATH3081 , DS50',
#  'EECE5614': 'EECE3468 , MATH3081 , MATH2331 , IE3412',
#  'EECE5626': 'EECE25 , EECE3468 , MATH3081',
#  'EECE5640': 'EECE3324 , CS3650',
#  'EECE5641': 'EECE2540 , EECE4534 , EECE3324 , CS3650 , CS3700 , EECE2540 , EECE75 , EECE7376 , CS5600',
#  'EECE5643': 'EECE2560 , CS3000',
#  'EECE5644': 'EECE3468 , MATH3081 , EECE74 , DS50 , MATH1215 , MATH2280 , IE3412 , CIVE3464 , BIOE2365 , MGSC2301',
#  'EECE5645': 'MATH3081 , EECE3468 , EECE2560 , CS3000 , EECE5644 , DS52 , DS5230',
#  'EECE5647': 'EECE2530',
#  'EECE5649': 'EECE3410',
#  'EECE5651': 'EECE2530 , MATH2341',
#  'EECE5652': 'EECE2150 , EECE2210 , BIOE3210 , EECE2530',
#  'EECE5653': 'MATH2341',
#  'EECE5654': 'BIOE3210 , EECE2150 , EECE2210 , EECE4646 , EECE2530',
#  'EECE5665': 'BIOE3210 , EECE2150 , EECE2210 , EECE25 , MATH2341 , EECE3468 , MATH3081',
#  'EECE5666': 'ME4555 , EECE25 , EECE3468',
#  'EECE5680': 'EECE2530 , EECE25',
#  'EECE5682': 'EECE2530',
#  'EECE5684': 'EECE2412 , EECE25',
#  'EECE5686': 'EECE2530',
#  'EECE5688': 'EECE2150',
#  'EECE5690': 'EECE2412 , EECE2530',
#  'EECE5692': 'EECE2530',
#  'EECE5693': 'EECE2530',
#  'EECE5697': 'EECE25',
#  'EECE5699': 'EECE3324 , CS3650 , CS5600',
#  'EECE7150': 'EECE5554',
#  'EECE7211': 'EECE70',
#  'EECE7213': 'EECE70',
#  'EECE7214': 'EECE70',
#  'EECE7215': 'EECE5580 , EECE7346',
#  'EECE7228': 'EECE5684 , EECE5684',
#  'EECE7242': 'EECE5649 , EECE7240',
#  'EECE7247': 'EECE7240 , EECE5649 , EECE5649',
#  'EECE7250': 'EECE5649 , EECE5649 , EECE7240',
#  'EECE7270': 'EECE72',
#  'EECE7271': 'EECE72',
#  'EECE7275': 'EECE72',
#  'EECE7293': 'EECE72',
#  'EECE7310': 'EECE74',
#  'EECE7336': 'EECE74 , EECE3468',
#  'EECE7337': 'EECE74',
#  'EECE7345': 'EECE5644 , EECE7323',
#  'EECE7346': 'EECE74',
#  'EECE7368': 'EECE75',
#  'EECE7376': 'CS3000 , EECE2560 , EECE75',
#  ...}

# %%
Gc = generate_course_network(curriculum_dict)

# %%
len(Gc)
# Out:
# 3259

# %%
#course with maximum prerequisites 
max_in_degree_node = max(Gc.in_degree(), key=lambda x: x[1])
# Print the node and its in-degree
print(f"Node with maximum in-degree: {max_in_degree_node[0]}, In-degree: {max_in_degree_node[1]}")
# Out:
# Node with maximum in-degree: PHTH4202, In-degree: 20

# %%
nx.find_cycle(Gc)
cycle = nx.find_cycle(Gc)
Gc.remove_edges_from(cycle)

# %%
Gc.remove_edges_from(nx.selfloop_edges(Gc))

# %%
#The longest chain of prerequisites
nx.dag_longest_path(Gc)
# nx.dag_longest_path_length(Gc)

# %%
longest_path = nx.dag_longest_path(Gc)
print(longest_path)

longest_path_edges = list(zip(longest_path, longest_path[1:]))
LG = Gc.edge_subgraph(longest_path_edges).copy()

pos = nx.spring_layout(LG, k=2, iterations=10) 
plt.figure(figsize=(8, 6))

# Draw the nodes and edges for the longest path only
nx.draw(LG, pos, with_labels=True, node_color="lightgreen", node_size=1000, font_size=10, arrows=True, edge_color='teal', width=2)


plt.title("Longest Path in DAG", fontsize=14)
plt.savefig('longest_path.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# Qs 5] Generating a network of CS PhD students collaborations

# %%
import networkx as nx
from scipy.io import mmread

# Load the matrix market file (.mtx)
file_path = 'ca-CSphd.mtx'
edges = []
with open(file_path, 'r') as f:
    for line in f:
        if line.startswith('%'):  # Skip comment lines starting with '%'
            continue

        u, v = map(int, line.split())
        edges.append((u, v))

# Create a directed graph
G = nx.DiGraph()

# Add edges to the graph
G.add_edges_from(edges)
G = G.to_undirected()

# %%
G.number_of_nodes()
# Out:
# 1882

# %%
G.number_of_edges()
# Out:
# 1740

# %%
def degree_distribution(G, number_of_bins=15, log_binning=True, density=True, directed=False):
   
    # Step 0: Do we want the directed or undirected degree distribution?
    if directed:
        if directed=='in':
            k = list(dict(G.in_degree()).values()) # get the in degree of each node
        elif directed=='out':
            k = list(dict(G.out_degree()).values()) # get the out degree of each node
        else:
            out_error = "Help! if directed!=False, the input needs to be either 'in' or 'out'"
            print(out_error)
            # Question: Is this the correct way to raise an error message in Python?
            #           See "raise" function...
            return out_error
    else:
        k = list(dict(G.degree()).values()) # get the degree of each node


    # Step 1: We will first need to define the support of our distribution
    kmax = np.max(k)    # get the maximum degree
    kmin = 0            # let's assume kmin must be 0


    # Step 2: Then we'll need to construct bins
    if log_binning:
        # array of bin edges including rightmost and leftmost
        bins = np.logspace(0, np.log10(kmax+1), number_of_bins+1)
    else:
        bins = np.linspace(0, kmax+1, num=number_of_bins+1)


    # Step 3: Then we can compute the histogram using numpy
    probs, _ = np.histogram(k, bins, density=density)


    # Step 4: Return not the "bins" but the midpoint between adjacent bin
    #         values. This is a better way to plot the distribution.
    bins_out = bins[1:] - np.diff(bins)/2.0
    
    return bins_out, probs

# %%
x, y = degree_distribution(G)
fig, ax = plt.subplots(1,1,figsize=(4.5,4),dpi=125)

ax.loglog(x, y,'o', color='teal', label='degree', alpha=0.8, mec='.1')


ax.set_xlabel(r"$k$",fontsize='large')
ax.set_ylabel(r"$P(k)$",fontsize='large')
ax.legend(fontsize='small')
ax.grid(linewidth=1.5, color='#999999', alpha=0.2, linestyle='-')
ax.set_title('CS PhD Collabs Degree Distribution')


plt.savefig('CS PhD Collabs Degree Distribution.png', dpi=425, bbox_inches='tight')
plt.savefig('CS PhD Collabs Degree Distribution.pdf', bbox_inches='tight')
plt.show()

# %%
x, y = degree_distribution(G)

# Betweenness centrality distribution
betweenness_centrality = nx.betweenness_centrality(G)
betweenness_values = list(betweenness_centrality.values())

# Clustering coefficient distribution
clustering_coefficient = nx.clustering(G)
clustering_values = list(clustering_coefficient.values())

fig, axs = plt.subplots(1, 3, figsize=(15, 5))

# Plot 1: Degree distribution
axs[0].loglog(x, y,'o', color='b', label='degree', alpha=0.8, mec='.1')
axs[0].set_title('Degree Distribution')
axs[0].set_xlabel('Degree')
axs[0].set_ylabel('Frequency')

# Plot 2: Betweenness centrality distribution
axs[1].hist(betweenness_values, bins=10, color='g', alpha=0.7)
axs[1].set_title('Betweenness Centrality Distribution')
axs[1].set_xlabel('Betweenness Centrality')
axs[1].set_ylabel('Frequency')

# Plot 3: Clustering coefficient distribution
axs[2].hist(clustering_values, bins=10, color='r', alpha=0.7)
axs[2].set_title('Clustering Coefficient Distribution')
axs[2].set_xlabel('Clustering Coefficient')
axs[2].set_ylabel('Frequency')

# Step 4: Display the plots
plt.tight_layout()
plt.savefig('CS PhD Collabs dd,bc,cc original.png', dpi=425, bbox_inches='tight')
plt.savefig('CS PhD Collabs dd,bc,cc original.pdf', bbox_inches='tight')
plt.show()

# %%
from collections import Counter

def configuration_model_from_degree_sequence(degree_sequence, return_simple=True):

    # Check if the degree sequence is valid (sum of degrees must be even)
    if sum(degree_sequence) % 2 != 0:
        raise ValueError("The sum of the degree sequence must be even.")

    # Create stubs list: node i appears degree_sequence[i] times
    stubs = []
    for node, degree in enumerate(degree_sequence):
        stubs.extend([node] * degree)

    # Shuffle stubs to randomize the pairing process
    np.random.shuffle(stubs)

    # Initialize an empty multigraph
    G = nx.MultiGraph()

    # Add nodes to the graph
    G.add_nodes_from(range(len(degree_sequence)))

    # Pair stubs to create edges
    while stubs:
        u = stubs.pop()
        v = stubs.pop()

        # Add the edge to the graph
        G.add_edge(u, v)

    if return_simple:
        # Convert the multigraph to a simple graph (remove parallel edges and self-loops)
        G_simple = nx.Graph(G)  # This removes parallel edges and self-loops by default

        return G_simple

    else:
        return G

# %%
G_randomized = configuration_model_from_degree_sequence(list(dict(G.degree()).values()),return_simple=True)

# %%
x, y = degree_distribution(G_randomized)

# Betweenness centrality distribution
betweenness_centrality = nx.betweenness_centrality(G_randomized)
betweenness_values = list(betweenness_centrality.values())

# Clustering coefficient distribution
clustering_coefficient = nx.clustering(G_randomized)
clustering_values = list(clustering_coefficient.values())

fig, axs = plt.subplots(1, 3, figsize=(15, 5))

# Plot 1: Degree distribution
axs[0].loglog(x, y,'o', color='b', label='degree', alpha=0.8, mec='.1')
axs[0].set_title('Degree Distribution')
axs[0].set_xlabel('Degree')
axs[0].set_ylabel('Frequency')

# Plot 2: Betweenness centrality distribution
axs[1].hist(betweenness_values, bins=10, color='g', alpha=0.7)
axs[1].set_title('Betweenness Centrality Distribution')
axs[1].set_xlabel('Betweenness Centrality')
axs[1].set_ylabel('Frequency')

# Plot 3: Clustering coefficient distribution
axs[2].hist(clustering_values, bins=10, color='r', alpha=0.7)
axs[2].set_title('Clustering Coefficient Distribution')
axs[2].set_xlabel('Clustering Coefficient')
axs[2].set_ylabel('Frequency')

# Step 4: Display the plots
plt.tight_layout()
plt.savefig('CS PhD Collabs dd,bc,cc random.png', dpi=425, bbox_inches='tight')
plt.savefig('CS PhD Collabs dd,bc,cc random.pdf', bbox_inches='tight')
plt.show()
